# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/googlecolab/colabtools/blob/master/notebooks/colab-github-demo.ipynb)
#
# <a name="0"></a>
# # Image Segmentation for Nuclei Data
#
# * [Kaggle Data Science Bowl 2018](https://www.kaggle.com/c/data-science-bowl-2018)
#
# ---
#
# ## Notebook Contents
#
# * [1. Load and Preprocess Data](#1)
# * [2. Define U-Net Architecture](#2)
# * [3. Fitting Model](#3)
# ___

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# set directory 
import os 
os.chdir('/content/drive/My Drive/thesis/image_segmentation') 
print('Working Directory:', os.getcwd()) 

# load packages 
import numpy as np 
import pandas as pd 
import keras.backend as K 
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split 

import tensorflow as tf 
from keras import Model 
from keras.layers import Input, Conv2D, MaxPool2D, Dropout 
from keras.layers import Conv2DTranspose, UpSampling2D, concatenate 
from keras.optimizers import Adam 
from keras.callbacks import ModelCheckpoint, EarlyStopping 
K.set_floatx('float32')
# Out:
# Working Directory: /content/drive/My Drive/thesis/image_segmentation

# %% [markdown]
# <a name="1"></a>
# # 1. Load and Preprocess Data
#
# * [Notebook Contents](#0)

# %%
def load_train_data(path): 
    data = np.load(path) 
    return data['images'], data['masks'] 

# load data 
path = 'nuclei_data/train_data.npz' 
X_train, y_train = load_train_data(path) 

# split into training and validation data 
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=7) 
print('Training Data Dimensions:') 
print(X_train.shape, y_train.shape) 
print('\nValidation Data Dimensions:') 
print(X_val.shape, y_val.shape)
# Out:
# Training Data Dimensions:
# (603, 128, 128, 3) (603, 128, 128, 1)
#
# Validation Data Dimensions:
# (67, 128, 128, 3) (67, 128, 128, 1)

# %% [markdown]
# <a name="2"></a>
# # 2. Define U-Net Architecture
#
# * [Notebook Contents](#0)

# %%
def dice_coef(y_true, y_pred, axis=(1, 2, 3), e=1e-5): 
    y_true = tf.cast(y_true, dtype=tf.float32) 
    y_pred = tf.cast(y_pred, dtype=tf.float32) 
    numerator = 2*K.sum(y_true*y_pred, axis=axis) + e 
    denominator = K.sum(y_true, axis=axis) + K.sum(y_pred, axis=axis) + e 
    return K.mean(numerator/denominator) 

def soft_dice(y_true, y_pred, axis=(1, 2, 3), e=1e-5): 
    y_true = tf.cast(y_true, dtype=tf.float32) 
    y_pred = tf.cast(y_pred, dtype=tf.float32) 
    numerator = 2*K.sum(y_true*y_pred, axis=axis) + e 
    denominator = K.sum(y_true**2, axis=axis) + K.sum(y_pred**2, axis=axis) + e 
    loss = 1 - K.mean(numerator/denominator) 
    return loss 

def conv_block(x_in, n_filt, kernel, activation, kernel_init, drop_size=0.2): 
    x = Conv2D(n_filt, kernel, padding='same', activation=activation, 
               kernel_initializer=kernel_init)(x_in) 
    x = Dropout(drop_size)(x) 
    x = Conv2D(n_filt, kernel, padding='same', activation=activation, 
               kernel_initializer=kernel_init)(x) 
    return x 

def pool(x_in, pool_size): 
    return MaxPool2D(pool_size=pool_size, padding='same')(x_in) 

def tr_conv(x_in, n_filt, kernel=(2,2), strides=(2,2)): 
    return Conv2DTranspose(n_filt, kernel, strides, padding='same')(x_in) 

def up_samp(x_in, size=(2,2)): 
    return UpSampling2D(size=size)(x_in) 

def encoder_block(x_in, n_filt, kernel, activation, kernel_init, pool_size=(2,2)): 
    c = conv_block(x_in, n_filt, kernel, activation, kernel_init) 
    p = pool(c, pool_size) 
    return c, p 

def decoder_trconv_block(x_in, x_skip, n_filt, kernel, activation, kernel_init, size=(2,2)):
    up = tr_conv(x_in, n_filt) 
    m = concatenate([up, x_skip]) 
    c = conv_block(m, n_filt, kernel, activation, kernel_init) 
    return c 

def decoder_upsamp_block(x_in, x_skip, n_filt, kernel, activation, kernel_init, size=(2,2)): 
    up = up_samp(x_in) 
    m = concatenate([up, x_skip]) 
    c = conv_block(m, n_filt, kernel, activation, kernel_init) 
    return c

# %%
def uNet(input_shape, loss, metrics, depth=4, base_filt_pow=6, lr=1e-3, name=None, 
         activation='relu', kernel=(3,3), kernel_init='he_normal', tr_conv=True): 
    inputs = Input(shape=input_shape) 
    # encoder 
    filts = [] 
    encoder_conv_layers, encoder_pool_layers = [], [] 
    for i in range(depth): 
        if len(encoder_conv_layers) == 0: 
            x_in = inputs 
        else: 
            x_in = encoder_pool_layers[-1] 
        filts.append(2**(base_filt_pow+i)) 
        c, p = encoder_block(x_in, filts[i], kernel, activation, kernel_init) 
        encoder_conv_layers.append(c) 
        encoder_pool_layers.append(p) 
    # bottleneck 
    n_filt = 2 ** (base_filt_pow+depth)
    mid = conv_block(encoder_pool_layers[-1], n_filt, kernel, activation, kernel_init) 
    # decoder 
    filts = np.flip(filts) 
    skips = np.flip(encoder_conv_layers) 
    decoder_layers = [] 
    for i in range(depth): 
        if len(decoder_layers) == 0: 
            x_in = mid 
        else: 
            x_in = decoder_layers[-1] 
        if tr_conv: 
            x = decoder_trconv_block(x_in, skips[i], filts[i], kernel, activation, kernel_init) 
        else: 
            x = decoder_upsamp_block(x_in, skips[i], filts[i], kernel, activation, kernel_init) 
        decoder_layers.append(x) 
    outputs = Conv2D(1, (1,1), activation='sigmoid')(decoder_layers[-1]) 
    # define model 
    model = Model(inputs=[inputs], outputs=[outputs], name=name) 
    model.compile(optimizer=Adam(learning_rate=lr), loss=loss, metrics=metrics) 
    return model 

# define model 
model = uNet(input_shape=X_train.shape[1:], 
             loss=soft_dice, metrics=[dice_coef], 
             name='UNet_Nuclei_Segmentation_Model') 
model.summary()
# Out:
# Model: "UNet_Nuclei_Segmentation_Model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128, 128, 64) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 64) 36928       dropout[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 64, 64)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 128)  73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64, 64, 128)  0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 128)  147584      dropout_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 128)  0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32, 32, 256)  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 256)  590080      dropout_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 256)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 512)  1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 16, 16, 512)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 512)  2359808     dropout_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 512)    0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 8, 8, 1024)   4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 8, 8, 1024)   0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 1024)   9438208     dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 16, 16, 512)  2097664     conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16, 16, 1024) 0           conv2d_transpose[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 512)  4719104     concatenate[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 16, 16, 512)  0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 512)  2359808     dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 32, 32, 256)  524544      conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 512)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 256)  1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 32, 32, 256)  0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 256)  590080      dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 64, 64, 128)  131200      conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 256)  0           conv2d_transpose_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 128)  295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 64, 64, 128)  0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 128)  147584      dropout_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 128, 128, 64) 32832       conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 128 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 64) 73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 128, 128, 64) 0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 64) 36928       dropout_8[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 1)  65          conv2d_17[0][0]
# ==================================================================================================
# Total params: 31,031,745
# Trainable params: 31,031,745
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# <a name="3"></a>
# # 3. Fitting Model
#
# * [Notebook Contents](#0)

# %%
def fit_model(model, path, X_train, y_train, X_val, y_val, 
              batch_size=16, epochs=100, patience=10): 
    # model output directory 
    if not os.path.exists('models/'): 
        os.makedirs('models/') 
    # define callbacks 
    cb = [ModelCheckpoint('models/{}'.format(path), monitor='val_loss', mode='min', verbose=1, 
                          save_best_only=True), 
          EarlyStopping(monitor='val_loss', patience=patience, restore_best_weights=True)] 
    # fit model 
    hist = model.fit(X_train, y_train, batch_size, epochs, callbacks=cb, 
                     validation_data=(X_val, y_val), shuffle=True) 
    return hist 

# fit model 
print('\nFitting model...') 
path='unet_fitted_model_2.h5' 
history = fit_model(model, path,
                    X_train, y_train, 
                    X_val, y_val,  
                    epochs=150, 
                    patience=10)
# Out:
# Fitting model...
# Epoch 1/150
#  2/38 [>.............................] - ETA: 7s - loss: 0.6120 - dice_coef: 0.2785WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1553s vs `on_train_batch_end` time: 0.2657s). Check your callbacks.
# 38/38 [==============================] - ETA: 0s - loss: 0.4776 - dice_coef: 0.4248WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0076s vs `on_test_batch_end` time: 0.1059s). Check your callbacks.
#
# Epoch 00001: val_loss improved from inf to 0.25552, saving model to models/unet_fitted_model_2.h5
# 38/38 [==============================] - 24s 624ms/step - loss: 0.4776 - dice_coef: 0.4248 - val_loss: 0.2555 - val_dice_coef: 0.7235
# Epoch 2/150
# 38/38 [==============================] - ETA: 0s - loss: 0.1949 - dice_coef: 0.7723
# Epoch 00002: val_loss improved from 0.25552 to 0.22279, saving model to models/unet_fitted_model_2.h5
# 38/38 [==============================] - 19s 504ms/step - loss: 0.1949 - dice_coef: 0.7723 - val_loss: 0.2228 - val_dice_coef: 0.7739
# Epoch 3/150
# 38/38 [==============================] - ETA: 0s - loss: 0.1744 - dice_coef: 0.7930
# Epoch 00003: val_loss improved from 0.22279 to 0.20850, saving model to models/unet_fitted_model_2.h5
# 38/38 [==============================] - 19s 504ms/step - loss: 0.1744 - dice_coef: 0.7930 - val_loss: 0.2085 - val_dice_coef: 0.7745
# Epoch 4/150
# 38/38 [==============================] - ETA: 0s - loss: 0.1685 - dice_coef: 0.7964
# Epoch 00004: val_loss improved from 0.20850 to 0.20689, saving model to models/unet_fitted_model_2.h5
# 38/38 [==============================] - 19s 505ms/step - loss: 0.1685 - dice_coef: 0.7964 - val_loss: 0.2069 - val_dice_coef: 0.7813
# Epoch 5/150
# 38/38 [==============================] - ETA: 0s - loss: 0.1692 - dice_coef: 0.7933
# Epoch 00005: val_loss did not improve from 0.20689
# 38/38 [==============================] - 16s 415ms/step - loss: 0.1692 - dice_coef: 0.7933 - val_loss: 0.2107 - val_dice_coef: 0.7793
# Epoch 6/150
# 38/38 [==============================] - ETA: 0s - loss: 0.1667 - dice_coef: 0.7982
# Epoch 00006: val_loss improved from 0.20689 to 0.20129, saving model to models/unet_fitted_model_2.h5
# 38/38 [==============================] - 20s 519ms/step - loss: 0.1667 - dice_coef: 0.7982 - val_loss: 0.2013 - val_dice_coef: 0.7878
# Epoch 7/150
# 38/38 [==============================] - ETA: 0s - loss: 0.1626 - dice_coef: 0.8010
# Epoch 00007: val_loss improved from 0.20129 to 0.19844, saving model to models/unet_fitted_model_2.h5
# 38/38 [==============================] - 19s 502ms/step - loss: 0.1626 - dice_coef: 0.8010 - val_loss: 0.1984 - val_dice_coef: 0.7913
# Epoch 8/150
# 38/38 [==============================] - ETA: 0s - loss: 0.1439 - dice_coef: 0.8204
# Epoch 00008: val_loss improved from 0.19844 to 0.14112, saving model to models/unet_fitted_model_2.h5
# 38/38 [==============================] - 19s 513ms/step - loss: 0.1439 - dice_coef: 0.8204 - val_loss: 0.1411 - val_dice_coef: 0.8347
# Epoch 9/150
# 38/38 [==============================] - ETA: 0s - loss: 0.1735 - dice_coef: 0.7800
# Epoch 00009: val_loss did not improve from 0.14112
# 38/38 [==============================] - 16s 414ms/step - loss: 0.1735 - dice_coef: 0.7800 - val_loss: 0.1637 - val_dice_coef: 0.8190
# Epoch 10/150
# 38/38 [==============================] - ETA: 0s - loss: 0.1269 - dice_coef: 0.8440
# Epoch 00010: val_loss improved from 0.14112 to 0.12951, saving model to models/unet_fitted_model_2.h5
# 38/38 [==============================] - 20s 529ms/step - loss: 0.1269 - dice_coef: 0.8440 - val_loss: 0.1295 - val_dice_coef: 0.8502
# Epoch 11/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0980 - dice_coef: 0.8704
# Epoch 00011: val_loss improved from 0.12951 to 0.09677, saving model to models/unet_fitted_model_2.h5
# 38/38 [==============================] - 19s 510ms/step - loss: 0.0980 - dice_coef: 0.8704 - val_loss: 0.0968 - val_dice_coef: 0.8754
# Epoch 12/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0849 - dice_coef: 0.8805
# Epoch 00012: val_loss improved from 0.09677 to 0.08875, saving model to models/unet_fitted_model_2.h5
# 38/38 [==============================] - 19s 508ms/step - loss: 0.0849 - dice_coef: 0.8805 - val_loss: 0.0888 - val_dice_coef: 0.8777
# Epoch 13/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0798 - dice_coef: 0.8821
# Epoch 00013: val_loss improved from 0.08875 to 0.07746, saving model to models/unet_fitted_model_2.h5
# 38/38 [==============================] - 19s 505ms/step - loss: 0.0798 - dice_coef: 0.8821 - val_loss: 0.0775 - val_dice_coef: 0.8831
# Epoch 14/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0752 - dice_coef: 0.8836
# Epoch 00014: val_loss did not improve from 0.07746
# 38/38 [==============================] - 16s 409ms/step - loss: 0.0752 - dice_coef: 0.8836 - val_loss: 0.0782 - val_dice_coef: 0.8746
# Epoch 15/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0743 - dice_coef: 0.8812
# Epoch 00015: val_loss improved from 0.07746 to 0.07359, saving model to models/unet_fitted_model_2.h5
# 38/38 [==============================] - 19s 502ms/step - loss: 0.0743 - dice_coef: 0.8812 - val_loss: 0.0736 - val_dice_coef: 0.8858
# Epoch 16/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0708 - dice_coef: 0.8826
# Epoch 00016: val_loss improved from 0.07359 to 0.06829, saving model to models/unet_fitted_model_2.h5
# 38/38 [==============================] - 19s 500ms/step - loss: 0.0708 - dice_coef: 0.8826 - val_loss: 0.0683 - val_dice_coef: 0.8885
# Epoch 17/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0688 - dice_coef: 0.8861
# Epoch 00017: val_loss improved from 0.06829 to 0.06634, saving model to models/unet_fitted_model_2.h5
# 38/38 [==============================] - 19s 503ms/step - loss: 0.0688 - dice_coef: 0.8861 - val_loss: 0.0663 - val_dice_coef: 0.8856
# Epoch 18/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0667 - dice_coef: 0.8857
# Epoch 00018: val_loss improved from 0.06634 to 0.06442, saving model to models/unet_fitted_model_2.h5
# 38/38 [==============================] - 19s 500ms/step - loss: 0.0667 - dice_coef: 0.8857 - val_loss: 0.0644 - val_dice_coef: 0.8898
# Epoch 19/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0651 - dice_coef: 0.8894
# Epoch 00019: val_loss improved from 0.06442 to 0.06164, saving model to models/unet_fitted_model_2.h5
# 38/38 [==============================] - 19s 508ms/step - loss: 0.0651 - dice_coef: 0.8894 - val_loss: 0.0616 - val_dice_coef: 0.8937
# Epoch 20/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0636 - dice_coef: 0.8925
# Epoch 00020: val_loss improved from 0.06164 to 0.06094, saving model to models/unet_fitted_model_2.h5
# 38/38 [==============================] - 19s 498ms/step - loss: 0.0636 - dice_coef: 0.8925 - val_loss: 0.0609 - val_dice_coef: 0.8856
# Epoch 21/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0643 - dice_coef: 0.8881
# Epoch 00021: val_loss did not improve from 0.06094
# 38/38 [==============================] - 16s 410ms/step - loss: 0.0643 - dice_coef: 0.8881 - val_loss: 0.0628 - val_dice_coef: 0.8909
# Epoch 22/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0638 - dice_coef: 0.8900
# Epoch 00022: val_loss improved from 0.06094 to 0.06055, saving model to models/unet_fitted_model_2.h5
# 38/38 [==============================] - 19s 510ms/step - loss: 0.0638 - dice_coef: 0.8900 - val_loss: 0.0605 - val_dice_coef: 0.8956
# Epoch 23/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0642 - dice_coef: 0.8908
# Epoch 00023: val_loss did not improve from 0.06055
# 38/38 [==============================] - 16s 410ms/step - loss: 0.0642 - dice_coef: 0.8908 - val_loss: 0.0616 - val_dice_coef: 0.8970
# Epoch 24/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0622 - dice_coef: 0.8931
# Epoch 00024: val_loss improved from 0.06055 to 0.05956, saving model to models/unet_fitted_model_2.h5
# 38/38 [==============================] - 19s 511ms/step - loss: 0.0622 - dice_coef: 0.8931 - val_loss: 0.0596 - val_dice_coef: 0.8986
# Epoch 25/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0614 - dice_coef: 0.8926
# Epoch 00025: val_loss did not improve from 0.05956
# 38/38 [==============================] - 16s 411ms/step - loss: 0.0614 - dice_coef: 0.8926 - val_loss: 0.0609 - val_dice_coef: 0.8961
# Epoch 26/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0622 - dice_coef: 0.8933
# Epoch 00026: val_loss did not improve from 0.05956
# 38/38 [==============================] - 16s 411ms/step - loss: 0.0622 - dice_coef: 0.8933 - val_loss: 0.0609 - val_dice_coef: 0.8981
# Epoch 27/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0615 - dice_coef: 0.8945
# Epoch 00027: val_loss improved from 0.05956 to 0.05802, saving model to models/unet_fitted_model_2.h5
# 38/38 [==============================] - 20s 515ms/step - loss: 0.0615 - dice_coef: 0.8945 - val_loss: 0.0580 - val_dice_coef: 0.9007
# Epoch 28/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0597 - dice_coef: 0.8963
# Epoch 00028: val_loss did not improve from 0.05802
# 38/38 [==============================] - 16s 411ms/step - loss: 0.0597 - dice_coef: 0.8963 - val_loss: 0.0584 - val_dice_coef: 0.8964
# Epoch 29/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0596 - dice_coef: 0.8966
# Epoch 00029: val_loss improved from 0.05802 to 0.05753, saving model to models/unet_fitted_model_2.h5
# 38/38 [==============================] - 19s 510ms/step - loss: 0.0596 - dice_coef: 0.8966 - val_loss: 0.0575 - val_dice_coef: 0.8941
# Epoch 30/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0608 - dice_coef: 0.8953
# Epoch 00030: val_loss did not improve from 0.05753
# 38/38 [==============================] - 16s 409ms/step - loss: 0.0608 - dice_coef: 0.8953 - val_loss: 0.0585 - val_dice_coef: 0.9002
# Epoch 31/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0601 - dice_coef: 0.8974
# Epoch 00031: val_loss did not improve from 0.05753
# 38/38 [==============================] - 16s 410ms/step - loss: 0.0601 - dice_coef: 0.8974 - val_loss: 0.0605 - val_dice_coef: 0.8999
# Epoch 32/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0590 - dice_coef: 0.8977
# Epoch 00032: val_loss did not improve from 0.05753
# 38/38 [==============================] - 16s 409ms/step - loss: 0.0590 - dice_coef: 0.8977 - val_loss: 0.0586 - val_dice_coef: 0.9012
# Epoch 33/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0583 - dice_coef: 0.8997
# Epoch 00033: val_loss improved from 0.05753 to 0.05661, saving model to models/unet_fitted_model_2.h5
# 38/38 [==============================] - 20s 525ms/step - loss: 0.0583 - dice_coef: 0.8997 - val_loss: 0.0566 - val_dice_coef: 0.8980
# Epoch 34/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0575 - dice_coef: 0.8991
# Epoch 00034: val_loss improved from 0.05661 to 0.05626, saving model to models/unet_fitted_model_2.h5
# 38/38 [==============================] - 19s 499ms/step - loss: 0.0575 - dice_coef: 0.8991 - val_loss: 0.0563 - val_dice_coef: 0.9047
# Epoch 35/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0572 - dice_coef: 0.9017
# Epoch 00035: val_loss did not improve from 0.05626
# 38/38 [==============================] - 16s 410ms/step - loss: 0.0572 - dice_coef: 0.9017 - val_loss: 0.0566 - val_dice_coef: 0.9010
# Epoch 36/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0575 - dice_coef: 0.8990
# Epoch 00036: val_loss did not improve from 0.05626
# 38/38 [==============================] - 16s 410ms/step - loss: 0.0575 - dice_coef: 0.8990 - val_loss: 0.0580 - val_dice_coef: 0.9032
# Epoch 37/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0570 - dice_coef: 0.9019
# Epoch 00037: val_loss did not improve from 0.05626
# 38/38 [==============================] - 16s 410ms/step - loss: 0.0570 - dice_coef: 0.9019 - val_loss: 0.0568 - val_dice_coef: 0.8997
# Epoch 38/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0572 - dice_coef: 0.9014
# Epoch 00038: val_loss improved from 0.05626 to 0.05536, saving model to models/unet_fitted_model_2.h5
# 38/38 [==============================] - 19s 507ms/step - loss: 0.0572 - dice_coef: 0.9014 - val_loss: 0.0554 - val_dice_coef: 0.8976
# Epoch 39/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0563 - dice_coef: 0.9012
# Epoch 00039: val_loss did not improve from 0.05536
# 38/38 [==============================] - 16s 411ms/step - loss: 0.0563 - dice_coef: 0.9012 - val_loss: 0.0559 - val_dice_coef: 0.9021
# Epoch 40/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0559 - dice_coef: 0.9025
# Epoch 00040: val_loss did not improve from 0.05536
# 38/38 [==============================] - 16s 410ms/step - loss: 0.0559 - dice_coef: 0.9025 - val_loss: 0.0562 - val_dice_coef: 0.9041
# Epoch 41/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0556 - dice_coef: 0.9044
# Epoch 00041: val_loss did not improve from 0.05536
# 38/38 [==============================] - 16s 410ms/step - loss: 0.0556 - dice_coef: 0.9044 - val_loss: 0.0562 - val_dice_coef: 0.9069
# Epoch 42/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0576 - dice_coef: 0.8983
# Epoch 00042: val_loss did not improve from 0.05536
# 38/38 [==============================] - 16s 409ms/step - loss: 0.0576 - dice_coef: 0.8983 - val_loss: 0.0581 - val_dice_coef: 0.8974
# Epoch 43/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0596 - dice_coef: 0.8948
# Epoch 00043: val_loss did not improve from 0.05536
# 38/38 [==============================] - 16s 409ms/step - loss: 0.0596 - dice_coef: 0.8948 - val_loss: 0.0568 - val_dice_coef: 0.8988
# Epoch 44/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0569 - dice_coef: 0.9001
# Epoch 00044: val_loss improved from 0.05536 to 0.05478, saving model to models/unet_fitted_model_2.h5
# 38/38 [==============================] - 19s 500ms/step - loss: 0.0569 - dice_coef: 0.9001 - val_loss: 0.0548 - val_dice_coef: 0.9043
# Epoch 45/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0559 - dice_coef: 0.8994
# Epoch 00045: val_loss did not improve from 0.05478
# 38/38 [==============================] - 16s 409ms/step - loss: 0.0559 - dice_coef: 0.8994 - val_loss: 0.0551 - val_dice_coef: 0.9065
# Epoch 46/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0555 - dice_coef: 0.9048
# Epoch 00046: val_loss did not improve from 0.05478
# 38/38 [==============================] - 16s 409ms/step - loss: 0.0555 - dice_coef: 0.9048 - val_loss: 0.0557 - val_dice_coef: 0.9032
# Epoch 47/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0557 - dice_coef: 0.9025
# Epoch 00047: val_loss did not improve from 0.05478
# 38/38 [==============================] - 16s 410ms/step - loss: 0.0557 - dice_coef: 0.9025 - val_loss: 0.0566 - val_dice_coef: 0.8924
# Epoch 48/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0576 - dice_coef: 0.9015
# Epoch 00048: val_loss did not improve from 0.05478
# 38/38 [==============================] - 16s 409ms/step - loss: 0.0576 - dice_coef: 0.9015 - val_loss: 0.0560 - val_dice_coef: 0.9054
# Epoch 49/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0538 - dice_coef: 0.9058
# Epoch 00049: val_loss improved from 0.05478 to 0.05354, saving model to models/unet_fitted_model_2.h5
# 38/38 [==============================] - 19s 505ms/step - loss: 0.0538 - dice_coef: 0.9058 - val_loss: 0.0535 - val_dice_coef: 0.9021
# Epoch 50/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0533 - dice_coef: 0.9071
# Epoch 00050: val_loss did not improve from 0.05354
# 38/38 [==============================] - 16s 409ms/step - loss: 0.0533 - dice_coef: 0.9071 - val_loss: 0.0540 - val_dice_coef: 0.9099
# Epoch 51/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0528 - dice_coef: 0.9073
# Epoch 00051: val_loss improved from 0.05354 to 0.05323, saving model to models/unet_fitted_model_2.h5
# 38/38 [==============================] - 19s 512ms/step - loss: 0.0528 - dice_coef: 0.9073 - val_loss: 0.0532 - val_dice_coef: 0.9065
# Epoch 52/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0532 - dice_coef: 0.9067
# Epoch 00052: val_loss did not improve from 0.05323
# 38/38 [==============================] - 16s 410ms/step - loss: 0.0532 - dice_coef: 0.9067 - val_loss: 0.0553 - val_dice_coef: 0.9097
# Epoch 53/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0538 - dice_coef: 0.9074
# Epoch 00053: val_loss improved from 0.05323 to 0.05317, saving model to models/unet_fitted_model_2.h5
# 38/38 [==============================] - 19s 508ms/step - loss: 0.0538 - dice_coef: 0.9074 - val_loss: 0.0532 - val_dice_coef: 0.9077
# Epoch 54/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0522 - dice_coef: 0.9091
# Epoch 00054: val_loss did not improve from 0.05317
# 38/38 [==============================] - 16s 410ms/step - loss: 0.0522 - dice_coef: 0.9091 - val_loss: 0.0550 - val_dice_coef: 0.9035
# Epoch 55/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0526 - dice_coef: 0.9072
# Epoch 00055: val_loss did not improve from 0.05317
# 38/38 [==============================] - 16s 410ms/step - loss: 0.0526 - dice_coef: 0.9072 - val_loss: 0.0549 - val_dice_coef: 0.9071
# Epoch 56/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0531 - dice_coef: 0.9080
# Epoch 00056: val_loss did not improve from 0.05317
# 38/38 [==============================] - 16s 410ms/step - loss: 0.0531 - dice_coef: 0.9080 - val_loss: 0.0538 - val_dice_coef: 0.9084
# Epoch 57/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0518 - dice_coef: 0.9090
# Epoch 00057: val_loss did not improve from 0.05317
# 38/38 [==============================] - 16s 410ms/step - loss: 0.0518 - dice_coef: 0.9090 - val_loss: 0.0533 - val_dice_coef: 0.9100
# Epoch 58/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0510 - dice_coef: 0.9104
# Epoch 00058: val_loss improved from 0.05317 to 0.05248, saving model to models/unet_fitted_model_2.h5
# 38/38 [==============================] - 19s 506ms/step - loss: 0.0510 - dice_coef: 0.9104 - val_loss: 0.0525 - val_dice_coef: 0.9083
# Epoch 59/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0507 - dice_coef: 0.9123
# Epoch 00059: val_loss did not improve from 0.05248
# 38/38 [==============================] - 16s 411ms/step - loss: 0.0507 - dice_coef: 0.9123 - val_loss: 0.0531 - val_dice_coef: 0.9117
# Epoch 60/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0502 - dice_coef: 0.9119
# Epoch 00060: val_loss did not improve from 0.05248
# 38/38 [==============================] - 16s 410ms/step - loss: 0.0502 - dice_coef: 0.9119 - val_loss: 0.0531 - val_dice_coef: 0.9095
# Epoch 61/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0506 - dice_coef: 0.9109
# Epoch 00061: val_loss improved from 0.05248 to 0.05213, saving model to models/unet_fitted_model_2.h5
# 38/38 [==============================] - 19s 506ms/step - loss: 0.0506 - dice_coef: 0.9109 - val_loss: 0.0521 - val_dice_coef: 0.9095
# Epoch 62/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0503 - dice_coef: 0.9127
# Epoch 00062: val_loss did not improve from 0.05213
# 38/38 [==============================] - 16s 410ms/step - loss: 0.0503 - dice_coef: 0.9127 - val_loss: 0.0545 - val_dice_coef: 0.9100
# Epoch 63/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0510 - dice_coef: 0.9118
# Epoch 00063: val_loss did not improve from 0.05213
# 38/38 [==============================] - 16s 409ms/step - loss: 0.0510 - dice_coef: 0.9118 - val_loss: 0.0538 - val_dice_coef: 0.9079
# Epoch 64/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0509 - dice_coef: 0.9108
# Epoch 00064: val_loss did not improve from 0.05213
# 38/38 [==============================] - 16s 410ms/step - loss: 0.0509 - dice_coef: 0.9108 - val_loss: 0.0535 - val_dice_coef: 0.9063
# Epoch 65/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0514 - dice_coef: 0.9109
# Epoch 00065: val_loss did not improve from 0.05213
# 38/38 [==============================] - 16s 411ms/step - loss: 0.0514 - dice_coef: 0.9109 - val_loss: 0.0534 - val_dice_coef: 0.9092
# Epoch 66/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0500 - dice_coef: 0.9121
# Epoch 00066: val_loss did not improve from 0.05213
# 38/38 [==============================] - 16s 410ms/step - loss: 0.0500 - dice_coef: 0.9121 - val_loss: 0.0528 - val_dice_coef: 0.9076
# Epoch 67/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0503 - dice_coef: 0.9132
# Epoch 00067: val_loss did not improve from 0.05213
# 38/38 [==============================] - 16s 410ms/step - loss: 0.0503 - dice_coef: 0.9132 - val_loss: 0.0529 - val_dice_coef: 0.9080
# Epoch 68/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0487 - dice_coef: 0.9139
# Epoch 00068: val_loss did not improve from 0.05213
# 38/38 [==============================] - 16s 410ms/step - loss: 0.0487 - dice_coef: 0.9139 - val_loss: 0.0527 - val_dice_coef: 0.9134
# Epoch 69/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0486 - dice_coef: 0.9159
# Epoch 00069: val_loss did not improve from 0.05213
# 38/38 [==============================] - 16s 409ms/step - loss: 0.0486 - dice_coef: 0.9159 - val_loss: 0.0539 - val_dice_coef: 0.9081
# Epoch 70/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0484 - dice_coef: 0.9156
# Epoch 00070: val_loss did not improve from 0.05213
# 38/38 [==============================] - 16s 410ms/step - loss: 0.0484 - dice_coef: 0.9156 - val_loss: 0.0530 - val_dice_coef: 0.9103
# Epoch 71/150
# 38/38 [==============================] - ETA: 0s - loss: 0.0479 - dice_coef: 0.9159
# Epoch 00071: val_loss did not improve from 0.05213
# 38/38 [==============================] - 16s 411ms/step - loss: 0.0479 - dice_coef: 0.9159 - val_loss: 0.0526 - val_dice_coef: 0.9121

# %% [markdown]
# <a name="4"></a>
# # 4. Evaluation Model
#
# * [Notebook Contents](#0)

# %%
def evaluate_model(model, X_val, y_val, history): 
    scores = model.evaluate(X_val, y_val) 
    print(' ') 
    print('Validation Loss:', scores[0]) 
    print('Validation DICE:', scores[1]) 
    print(' ') 
    print('Plotting Loss and DICE Coefficient During Training:') 
    pd.DataFrame(history.history).plot(figsize=(10, 6)) 
    plt.grid(True) 
    plt.gca().set_ylim(0, 1) 
    plt.show() 

# model evaluation 
evaluate_model(model, X_val, y_val, history)
# Out:
# 2/3 [===================>..........] - ETA: 0s - loss: 0.0519 - dice_coef: 0.9094WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0098s vs `on_test_batch_end` time: 0.2025s). Check your callbacks.
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0521 - dice_coef: 0.9096
#
# Validation Loss: 0.05213107541203499
# Validation DICE: 0.9095733761787415
#
# Plotting Loss and DICE Coefficient During Training:

# %% [markdown]
# <a name="5"></a>
# # 5. Get Predictions and Plot
#
# * [Notebook Contents](#0)

# %%
# get predictions 
preds_train = model.predict(X_train, verbose=1) 
preds_val = model.predict(X_val, verbose=1) 

# create binary mask 
pred_train_masks = (preds_train > 0.5).astype(np.uint8) 
preds_val_masks = (preds_val > 0.5).astype(np.uint8) 

# functions to visualize predictions 
def plot_img(X, cmap=None):  
    plt.imshow(X, cmap=cmap) 
    plt.axis('off') 

def plot_train_predictions(X, y, preds, cmap=None): 
    # get random observation number 
    idx = np.random.randint(len(X)) 
    # plot training image, mask, and prediction 
    plt.figure(figsize=(10, 6)) 
    plt.subplot(1, 3, 1) 
    plot_img(X[idx], cmap=cmap) 
    plt.title('Image', size=16) 
    plt.subplot(1, 3, 2) 
    plot_img(np.squeeze(y[idx]), cmap=cmap) 
    plt.title('Mask', size=16) 
    plt.subplot(1, 3, 3) 
    plot_img(np.squeeze(preds[idx]), cmap=cmap) 
    plt.title('Predicted Mask', size=16) 
    plt.suptitle('Observation Number: {}'.format(idx), size=18) 
    plt.tight_layout()
# Out:
#  2/19 [==>...........................] - ETA: 1sWARNING:tensorflow:Callbacks method `on_predict_batch_end` is slow compared to the batch time (batch time: 0.0078s vs `on_predict_batch_end` time: 0.1915s). Check your callbacks.
# 19/19 [==============================] - 7s 364ms/step
# 2/3 [===================>..........] - ETA: 0sWARNING:tensorflow:Callbacks method `on_predict_batch_end` is slow compared to the batch time (batch time: 0.0066s vs `on_predict_batch_end` time: 0.1976s). Check your callbacks.
# 3/3 [==============================] - 0s 153ms/step

# %%
# plot predictions 
plot_train_predictions(X_train, y_train, pred_train_masks)

# %%
# plot predictions 
plot_train_predictions(X_train, y_train, pred_train_masks)

# %%
# plot predictions 
plot_train_predictions(X_train, y_train, pred_train_masks)

# %%
# plot predictions 
plot_train_predictions(X_val, y_val, preds_val_masks)

# %%
# plot predictions 
plot_train_predictions(X_val, y_val, preds_val_masks)

# %%
# plot predictions 
plot_train_predictions(X_val, y_val, preds_val_masks)
