# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/googlecolab/colabtools/blob/master/notebooks/colab-github-demo.ipynb)
#
# <a name="0"></a>
# # Image Segmentation for Nuclei Data
#
# * [Kaggle Data Science Bowl 2018](https://www.kaggle.com/c/data-science-bowl-2018)
#
# ---
#
# ## Notebook Contents
#
# * [1. Load and Preprocess Data](#1)
# * [2. Define U-Net Architecture](#2)
# * [3. Fitting Model](#3)
# * [4. Model Evaluation](#4)
# * [5. Get Predictions and Plot](#5)
# * [6. Summary](#6)
# ___

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# set directory 
import os 
os.chdir('/content/drive/My Drive/thesis/image_segmentation') 
print('Working Directory:', os.getcwd()) 

# load packages 
import numpy as np 
import pandas as pd 
import keras.backend as K 
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split 

import tensorflow as tf 
from keras import Model 
from keras.layers import Input, Conv2D, MaxPool2D, Dropout 
from keras.layers import Conv2DTranspose, UpSampling2D, concatenate 
from keras.optimizers import Adam 
from keras.callbacks import ModelCheckpoint, EarlyStopping 
K.set_floatx('float32')
# Out:
# Working Directory: /content/drive/My Drive/thesis/image_segmentation

# %% [markdown]
# <a name="1"></a>
# # 1. Load and Preprocess Data
#
# [Notebook Contents](#0) | [Summary](#6)
#
# ---
#
# * 670 total observations
# * 70% for train data: 469 observations
# * 20% for test data: 140 observations
# * 10% for validation data: 61 observations

# %%
def load_train_data(path): 
    data = np.load(path) 
    return data['images'], data['masks'] 

# load data 
path = 'nuclei_data/train_data.npz' 
X, y = load_train_data(path) 

# split into training, testing, validation data 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=7) 
X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=0.3, random_state=7) 
print('Training Data Dimensions:') 
print('X_train = ', X_train.shape) 
print('y_train = ', y_train.shape) 
print('\nTesting Data Dimensions:') 
print('X_test = ', X_test.shape) 
print('y_test = ', y_test.shape) 
print('\nValidation Data Dimensions:') 
print('X_val = ', X_val.shape) 
print('y_val = ', y_val.shape)
# Out:
# Training Data Dimensions:
# X_train =  (469, 128, 128, 3)
# y_train =  (469, 128, 128, 1)
#
# Testing Data Dimensions:
# X_test =  (140, 128, 128, 3)
# y_test =  (140, 128, 128, 1)
#
# Validation Data Dimensions:
# X_val =  (61, 128, 128, 3)
# y_val =  (61, 128, 128, 1)

# %% [markdown]
# <a name="2"></a>
# # 2. Define U-Net Architecture
#
# [Notebook Contents](#0) | [Summary](#6)

# %%
def dice_coef(y_true, y_pred, axis=(1, 2, 3), e=1e-5): 
    y_true = tf.cast(y_true, dtype=tf.float32) 
    y_pred = tf.cast(y_pred, dtype=tf.float32) 
    numerator = 2*K.sum(y_true*y_pred, axis=axis) + e 
    denominator = K.sum(y_true, axis=axis) + K.sum(y_pred, axis=axis) + e 
    return K.mean(numerator/denominator) 

def soft_dice(y_true, y_pred, axis=(1, 2, 3), e=1e-5): 
    y_true = tf.cast(y_true, dtype=tf.float32) 
    y_pred = tf.cast(y_pred, dtype=tf.float32) 
    numerator = 2*K.sum(y_true*y_pred, axis=axis) + e 
    denominator = K.sum(y_true**2, axis=axis) + K.sum(y_pred**2, axis=axis) + e 
    loss = 1 - K.mean(numerator/denominator) 
    return loss 

def conv_block(x_in, n_filt, kernel, activation, kernel_init, drop_size=0.2): 
    x = Conv2D(n_filt, kernel, padding='same', activation=activation, 
               kernel_initializer=kernel_init)(x_in) 
    x = Dropout(drop_size)(x) 
    x = Conv2D(n_filt, kernel, padding='same', activation=activation, 
               kernel_initializer=kernel_init)(x) 
    return x 

def pool(x_in, pool_size): 
    return MaxPool2D(pool_size=pool_size, padding='same')(x_in) 

def tr_conv(x_in, n_filt, kernel=(2,2), strides=(2,2)): 
    return Conv2DTranspose(n_filt, kernel, strides, padding='same')(x_in) 

def up_samp(x_in, size=(2,2)): 
    return UpSampling2D(size=size)(x_in) 

def encoder_block(x_in, n_filt, kernel, activation, kernel_init, pool_size=(2,2)): 
    c = conv_block(x_in, n_filt, kernel, activation, kernel_init) 
    p = pool(c, pool_size) 
    return c, p 

def decoder_trconv_block(x_in, x_skip, n_filt, kernel, activation, kernel_init, size=(2,2)):
    up = tr_conv(x_in, n_filt) 
    m = concatenate([up, x_skip]) 
    c = conv_block(m, n_filt, kernel, activation, kernel_init) 
    return c 

def decoder_upsamp_block(x_in, x_skip, n_filt, kernel, activation, kernel_init, size=(2,2)): 
    up = up_samp(x_in) 
    m = concatenate([up, x_skip]) 
    c = conv_block(m, n_filt, kernel, activation, kernel_init) 
    return c

# %%
def uNet(input_shape, loss, metrics, depth=4, base_filt_pow=6, lr=1e-3, name=None, 
         activation='relu', kernel=(3,3), kernel_init='he_normal', tr_conv=True): 
    inputs = Input(shape=input_shape) 
    # encoder 
    filts = [] 
    encoder_conv_layers, encoder_pool_layers = [], [] 
    for i in range(depth): 
        if len(encoder_conv_layers) == 0: 
            x_in = inputs 
        else: 
            x_in = encoder_pool_layers[-1] 
        filts.append(2**(base_filt_pow+i)) 
        c, p = encoder_block(x_in, filts[i], kernel, activation, kernel_init) 
        encoder_conv_layers.append(c) 
        encoder_pool_layers.append(p) 
    # bottleneck 
    n_filt = 2 ** (base_filt_pow+depth)
    mid = conv_block(encoder_pool_layers[-1], n_filt, kernel, activation, kernel_init) 
    # decoder 
    filts = np.flip(filts) 
    skips = np.flip(encoder_conv_layers) 
    decoder_layers = [] 
    for i in range(depth): 
        if len(decoder_layers) == 0: 
            x_in = mid 
        else: 
            x_in = decoder_layers[-1] 
        if tr_conv: 
            x = decoder_trconv_block(x_in, skips[i], filts[i], kernel, activation, kernel_init) 
        else: 
            x = decoder_upsamp_block(x_in, skips[i], filts[i], kernel, activation, kernel_init) 
        decoder_layers.append(x) 
    outputs = Conv2D(1, (1,1), activation='sigmoid')(decoder_layers[-1]) 
    # define model 
    model = Model(inputs=[inputs], outputs=[outputs], name=name) 
    model.compile(optimizer=Adam(learning_rate=lr), loss=loss, metrics=metrics) 
    return model 

# define model 
model = uNet(input_shape=X_train.shape[1:], 
             loss=soft_dice, metrics=[dice_coef], 
             name='UNet_Nuclei_Segmentation_Model') 
model.summary()
# Out:
# Model: "UNet_Nuclei_Segmentation_Model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128, 128, 64) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 64) 36928       dropout[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 64, 64)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 128)  73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64, 64, 128)  0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 128)  147584      dropout_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 128)  0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32, 32, 256)  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 256)  590080      dropout_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 256)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 512)  1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 16, 16, 512)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 512)  2359808     dropout_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 512)    0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 8, 8, 1024)   4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 8, 8, 1024)   0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 1024)   9438208     dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 16, 16, 512)  2097664     conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16, 16, 1024) 0           conv2d_transpose[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 512)  4719104     concatenate[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 16, 16, 512)  0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 512)  2359808     dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 32, 32, 256)  524544      conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 512)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 256)  1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 32, 32, 256)  0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 256)  590080      dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 64, 64, 128)  131200      conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 256)  0           conv2d_transpose_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 128)  295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 64, 64, 128)  0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 128)  147584      dropout_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 128, 128, 64) 32832       conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 128 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 64) 73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 128, 128, 64) 0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 64) 36928       dropout_8[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 1)  65          conv2d_17[0][0]
# ==================================================================================================
# Total params: 31,031,745
# Trainable params: 31,031,745
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# The U-Net model has 31,031,745 total trainable parameters that will be learnt when the model is fit.
#
# ---
#
# <a name="3"></a>
# # 3. Fitting Model
#
# [Notebook Contents](#0) | [Summary](#6)
#
# ---
#
# * The model is fit for 150 epochs using a batch size of 16
# * Early stopping with a patience of 15 and the best weights will be restored once training stops

# %%
def fit_model(model, path, X_train, y_train, X_val, y_val, 
              batch_size=16, epochs=100, patience=10): 
    # model output directory 
    if not os.path.exists('models/'): 
        os.makedirs('models/') 
    # define callbacks 
    cb = [ModelCheckpoint('models/{}'.format(path), monitor='val_loss', mode='min', verbose=1, 
                          save_best_only=True), 
          EarlyStopping(monitor='val_loss', patience=patience, restore_best_weights=True)] 
    # fit model 
    hist = model.fit(X_train, y_train, batch_size, epochs, callbacks=cb, 
                     validation_data=(X_val, y_val), shuffle=True) 
    return hist 

# fit model 
print('\nFitting model...') 
path='unet_fitted_model.h5' 
history = fit_model(model, path,
                    X_train, y_train, 
                    X_test, y_test,  
                    epochs=150, 
                    patience=15)
# Out:
# Fitting model...
# Epoch 1/150
#  2/30 [=>............................] - ETA: 2s - loss: 0.6542 - dice_coef: 0.2309WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0695s vs `on_train_batch_end` time: 0.1257s). Check your callbacks.
# 30/30 [==============================] - ETA: 0s - loss: 0.5051 - dice_coef: 0.4023WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0043s vs `on_test_batch_end` time: 0.0501s). Check your callbacks.
#
# Epoch 00001: val_loss improved from inf to 0.23283, saving model to models/unet_fitted_model.h5
# 30/30 [==============================] - 10s 330ms/step - loss: 0.5051 - dice_coef: 0.4023 - val_loss: 0.2328 - val_dice_coef: 0.7506
# Epoch 2/150
# 30/30 [==============================] - ETA: 0s - loss: 0.2231 - dice_coef: 0.7518
# Epoch 00002: val_loss improved from 0.23283 to 0.18275, saving model to models/unet_fitted_model.h5
# 30/30 [==============================] - 7s 248ms/step - loss: 0.2231 - dice_coef: 0.7518 - val_loss: 0.1827 - val_dice_coef: 0.7699
# Epoch 3/150
# 30/30 [==============================] - ETA: 0s - loss: 0.1851 - dice_coef: 0.7819
# Epoch 00003: val_loss improved from 0.18275 to 0.16869, saving model to models/unet_fitted_model.h5
# 30/30 [==============================] - 7s 249ms/step - loss: 0.1851 - dice_coef: 0.7819 - val_loss: 0.1687 - val_dice_coef: 0.7995
# Epoch 4/150
# 30/30 [==============================] - ETA: 0s - loss: 0.1773 - dice_coef: 0.7884
# Epoch 00004: val_loss improved from 0.16869 to 0.16421, saving model to models/unet_fitted_model.h5
# 30/30 [==============================] - 7s 247ms/step - loss: 0.1773 - dice_coef: 0.7884 - val_loss: 0.1642 - val_dice_coef: 0.7960
# Epoch 5/150
# 30/30 [==============================] - ETA: 0s - loss: 0.1768 - dice_coef: 0.7868
# Epoch 00005: val_loss improved from 0.16421 to 0.16036, saving model to models/unet_fitted_model.h5
# 30/30 [==============================] - 8s 253ms/step - loss: 0.1768 - dice_coef: 0.7868 - val_loss: 0.1604 - val_dice_coef: 0.7991
# Epoch 6/150
# 30/30 [==============================] - ETA: 0s - loss: 0.1702 - dice_coef: 0.7956
# Epoch 00006: val_loss improved from 0.16036 to 0.15792, saving model to models/unet_fitted_model.h5
# 30/30 [==============================] - 8s 251ms/step - loss: 0.1702 - dice_coef: 0.7956 - val_loss: 0.1579 - val_dice_coef: 0.8078
# Epoch 7/150
# 30/30 [==============================] - ETA: 0s - loss: 0.1693 - dice_coef: 0.7889
# Epoch 00007: val_loss improved from 0.15792 to 0.15742, saving model to models/unet_fitted_model.h5
# 30/30 [==============================] - 8s 252ms/step - loss: 0.1693 - dice_coef: 0.7889 - val_loss: 0.1574 - val_dice_coef: 0.8044
# Epoch 8/150
# 30/30 [==============================] - ETA: 0s - loss: 0.1469 - dice_coef: 0.8166
# Epoch 00008: val_loss improved from 0.15742 to 0.13783, saving model to models/unet_fitted_model.h5
# 30/30 [==============================] - 8s 251ms/step - loss: 0.1469 - dice_coef: 0.8166 - val_loss: 0.1378 - val_dice_coef: 0.8308
# Epoch 9/150
# 30/30 [==============================] - ETA: 0s - loss: 0.1215 - dice_coef: 0.8365
# Epoch 00009: val_loss improved from 0.13783 to 0.11899, saving model to models/unet_fitted_model.h5
# 30/30 [==============================] - 8s 254ms/step - loss: 0.1215 - dice_coef: 0.8365 - val_loss: 0.1190 - val_dice_coef: 0.8324
# Epoch 10/150
# 30/30 [==============================] - ETA: 0s - loss: 0.1240 - dice_coef: 0.8259
# Epoch 00010: val_loss improved from 0.11899 to 0.09685, saving model to models/unet_fitted_model.h5
# 30/30 [==============================] - 8s 254ms/step - loss: 0.1240 - dice_coef: 0.8259 - val_loss: 0.0968 - val_dice_coef: 0.8527
# Epoch 11/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0940 - dice_coef: 0.8544
# Epoch 00011: val_loss improved from 0.09685 to 0.07698, saving model to models/unet_fitted_model.h5
# 30/30 [==============================] - 8s 257ms/step - loss: 0.0940 - dice_coef: 0.8544 - val_loss: 0.0770 - val_dice_coef: 0.8783
# Epoch 12/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0810 - dice_coef: 0.8712
# Epoch 00012: val_loss did not improve from 0.07698
# 30/30 [==============================] - 6s 205ms/step - loss: 0.0810 - dice_coef: 0.8712 - val_loss: 0.0792 - val_dice_coef: 0.8764
# Epoch 13/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0789 - dice_coef: 0.8760
# Epoch 00013: val_loss improved from 0.07698 to 0.07610, saving model to models/unet_fitted_model.h5
# 30/30 [==============================] - 8s 272ms/step - loss: 0.0789 - dice_coef: 0.8760 - val_loss: 0.0761 - val_dice_coef: 0.8844
# Epoch 14/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0774 - dice_coef: 0.8738
# Epoch 00014: val_loss improved from 0.07610 to 0.07416, saving model to models/unet_fitted_model.h5
# 30/30 [==============================] - 8s 260ms/step - loss: 0.0774 - dice_coef: 0.8738 - val_loss: 0.0742 - val_dice_coef: 0.8869
# Epoch 15/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0742 - dice_coef: 0.8786
# Epoch 00015: val_loss improved from 0.07416 to 0.06730, saving model to models/unet_fitted_model.h5
# 30/30 [==============================] - 8s 262ms/step - loss: 0.0742 - dice_coef: 0.8786 - val_loss: 0.0673 - val_dice_coef: 0.8864
# Epoch 16/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0724 - dice_coef: 0.8771
# Epoch 00016: val_loss improved from 0.06730 to 0.06259, saving model to models/unet_fitted_model.h5
# 30/30 [==============================] - 8s 257ms/step - loss: 0.0724 - dice_coef: 0.8771 - val_loss: 0.0626 - val_dice_coef: 0.8930
# Epoch 17/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0701 - dice_coef: 0.8836
# Epoch 00017: val_loss improved from 0.06259 to 0.06256, saving model to models/unet_fitted_model.h5
# 30/30 [==============================] - 8s 257ms/step - loss: 0.0701 - dice_coef: 0.8836 - val_loss: 0.0626 - val_dice_coef: 0.8972
# Epoch 18/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0685 - dice_coef: 0.8846
# Epoch 00018: val_loss improved from 0.06256 to 0.06216, saving model to models/unet_fitted_model.h5
# 30/30 [==============================] - 8s 262ms/step - loss: 0.0685 - dice_coef: 0.8846 - val_loss: 0.0622 - val_dice_coef: 0.8983
# Epoch 19/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0688 - dice_coef: 0.8850
# Epoch 00019: val_loss did not improve from 0.06216
# 30/30 [==============================] - 6s 207ms/step - loss: 0.0688 - dice_coef: 0.8850 - val_loss: 0.0659 - val_dice_coef: 0.8941
# Epoch 20/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0683 - dice_coef: 0.8854
# Epoch 00020: val_loss did not improve from 0.06216
# 30/30 [==============================] - 6s 208ms/step - loss: 0.0683 - dice_coef: 0.8854 - val_loss: 0.0627 - val_dice_coef: 0.8947
# Epoch 21/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0673 - dice_coef: 0.8838
# Epoch 00021: val_loss improved from 0.06216 to 0.06088, saving model to models/unet_fitted_model.h5
# 30/30 [==============================] - 9s 300ms/step - loss: 0.0673 - dice_coef: 0.8838 - val_loss: 0.0609 - val_dice_coef: 0.8978
# Epoch 22/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0671 - dice_coef: 0.8857
# Epoch 00022: val_loss did not improve from 0.06088
# 30/30 [==============================] - 6s 207ms/step - loss: 0.0671 - dice_coef: 0.8857 - val_loss: 0.0686 - val_dice_coef: 0.8893
# Epoch 23/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0676 - dice_coef: 0.8842
# Epoch 00023: val_loss improved from 0.06088 to 0.05898, saving model to models/unet_fitted_model.h5
# 30/30 [==============================] - 8s 258ms/step - loss: 0.0676 - dice_coef: 0.8842 - val_loss: 0.0590 - val_dice_coef: 0.8989
# Epoch 24/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0661 - dice_coef: 0.8851
# Epoch 00024: val_loss did not improve from 0.05898
# 30/30 [==============================] - 6s 208ms/step - loss: 0.0661 - dice_coef: 0.8851 - val_loss: 0.0614 - val_dice_coef: 0.9019
# Epoch 25/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0647 - dice_coef: 0.8915
# Epoch 00025: val_loss did not improve from 0.05898
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0647 - dice_coef: 0.8915 - val_loss: 0.0613 - val_dice_coef: 0.8994
# Epoch 26/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0632 - dice_coef: 0.8916
# Epoch 00026: val_loss improved from 0.05898 to 0.05803, saving model to models/unet_fitted_model.h5
# 30/30 [==============================] - 9s 301ms/step - loss: 0.0632 - dice_coef: 0.8916 - val_loss: 0.0580 - val_dice_coef: 0.8967
# Epoch 27/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0631 - dice_coef: 0.8915
# Epoch 00027: val_loss did not improve from 0.05803
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0631 - dice_coef: 0.8915 - val_loss: 0.0594 - val_dice_coef: 0.8965
# Epoch 28/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0622 - dice_coef: 0.8930
# Epoch 00028: val_loss improved from 0.05803 to 0.05725, saving model to models/unet_fitted_model.h5
# 30/30 [==============================] - 8s 258ms/step - loss: 0.0622 - dice_coef: 0.8930 - val_loss: 0.0572 - val_dice_coef: 0.9007
# Epoch 29/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0607 - dice_coef: 0.8937
# Epoch 00029: val_loss did not improve from 0.05725
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0607 - dice_coef: 0.8937 - val_loss: 0.0574 - val_dice_coef: 0.9071
# Epoch 30/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0619 - dice_coef: 0.8919
# Epoch 00030: val_loss did not improve from 0.05725
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0619 - dice_coef: 0.8919 - val_loss: 0.0580 - val_dice_coef: 0.9029
# Epoch 31/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0603 - dice_coef: 0.8955
# Epoch 00031: val_loss improved from 0.05725 to 0.05655, saving model to models/unet_fitted_model.h5
# 30/30 [==============================] - 9s 306ms/step - loss: 0.0603 - dice_coef: 0.8955 - val_loss: 0.0566 - val_dice_coef: 0.8976
# Epoch 32/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0616 - dice_coef: 0.8940
# Epoch 00032: val_loss did not improve from 0.05655
# 30/30 [==============================] - 6s 210ms/step - loss: 0.0616 - dice_coef: 0.8940 - val_loss: 0.0585 - val_dice_coef: 0.9036
# Epoch 33/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0601 - dice_coef: 0.8991
# Epoch 00033: val_loss did not improve from 0.05655
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0601 - dice_coef: 0.8991 - val_loss: 0.0578 - val_dice_coef: 0.9040
# Epoch 34/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0597 - dice_coef: 0.8993
# Epoch 00034: val_loss did not improve from 0.05655
# 30/30 [==============================] - 6s 210ms/step - loss: 0.0597 - dice_coef: 0.8993 - val_loss: 0.0598 - val_dice_coef: 0.9049
# Epoch 35/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0592 - dice_coef: 0.8983
# Epoch 00035: val_loss did not improve from 0.05655
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0592 - dice_coef: 0.8983 - val_loss: 0.0568 - val_dice_coef: 0.8991
# Epoch 36/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0632 - dice_coef: 0.8919
# Epoch 00036: val_loss did not improve from 0.05655
# 30/30 [==============================] - 6s 210ms/step - loss: 0.0632 - dice_coef: 0.8919 - val_loss: 0.0610 - val_dice_coef: 0.9029
# Epoch 37/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0627 - dice_coef: 0.8935
# Epoch 00037: val_loss did not improve from 0.05655
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0627 - dice_coef: 0.8935 - val_loss: 0.0573 - val_dice_coef: 0.8981
# Epoch 38/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0609 - dice_coef: 0.8973
# Epoch 00038: val_loss did not improve from 0.05655
# 30/30 [==============================] - 6s 210ms/step - loss: 0.0609 - dice_coef: 0.8973 - val_loss: 0.0593 - val_dice_coef: 0.9019
# Epoch 39/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0603 - dice_coef: 0.8958
# Epoch 00039: val_loss improved from 0.05655 to 0.05644, saving model to models/unet_fitted_model.h5
# 30/30 [==============================] - 9s 304ms/step - loss: 0.0603 - dice_coef: 0.8958 - val_loss: 0.0564 - val_dice_coef: 0.9072
# Epoch 40/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0580 - dice_coef: 0.9016
# Epoch 00040: val_loss improved from 0.05644 to 0.05582, saving model to models/unet_fitted_model.h5
# 30/30 [==============================] - 8s 260ms/step - loss: 0.0580 - dice_coef: 0.9016 - val_loss: 0.0558 - val_dice_coef: 0.9048
# Epoch 41/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0560 - dice_coef: 0.9025
# Epoch 00041: val_loss improved from 0.05582 to 0.05502, saving model to models/unet_fitted_model.h5
# 30/30 [==============================] - 8s 259ms/step - loss: 0.0560 - dice_coef: 0.9025 - val_loss: 0.0550 - val_dice_coef: 0.9097
# Epoch 42/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0578 - dice_coef: 0.8992
# Epoch 00042: val_loss did not improve from 0.05502
# 30/30 [==============================] - 6s 211ms/step - loss: 0.0578 - dice_coef: 0.8992 - val_loss: 0.0721 - val_dice_coef: 0.8880
# Epoch 43/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0686 - dice_coef: 0.8859
# Epoch 00043: val_loss did not improve from 0.05502
# 30/30 [==============================] - 6s 211ms/step - loss: 0.0686 - dice_coef: 0.8859 - val_loss: 0.0804 - val_dice_coef: 0.8778
# Epoch 44/150
# 30/30 [==============================] - ETA: 0s - loss: 0.1954 - dice_coef: 0.7632
# Epoch 00044: val_loss did not improve from 0.05502
# 30/30 [==============================] - 6s 210ms/step - loss: 0.1954 - dice_coef: 0.7632 - val_loss: 0.0636 - val_dice_coef: 0.8882
# Epoch 45/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0950 - dice_coef: 0.8584
# Epoch 00045: val_loss did not improve from 0.05502
# 30/30 [==============================] - 6s 210ms/step - loss: 0.0950 - dice_coef: 0.8584 - val_loss: 0.0655 - val_dice_coef: 0.8844
# Epoch 46/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0737 - dice_coef: 0.8785
# Epoch 00046: val_loss did not improve from 0.05502
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0737 - dice_coef: 0.8785 - val_loss: 0.0600 - val_dice_coef: 0.9045
# Epoch 47/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0671 - dice_coef: 0.8891
# Epoch 00047: val_loss did not improve from 0.05502
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0671 - dice_coef: 0.8891 - val_loss: 0.0638 - val_dice_coef: 0.8956
# Epoch 48/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0668 - dice_coef: 0.8889
# Epoch 00048: val_loss did not improve from 0.05502
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0668 - dice_coef: 0.8889 - val_loss: 0.0581 - val_dice_coef: 0.9028
# Epoch 49/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0640 - dice_coef: 0.8916
# Epoch 00049: val_loss did not improve from 0.05502
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0640 - dice_coef: 0.8916 - val_loss: 0.0575 - val_dice_coef: 0.9020
# Epoch 50/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0628 - dice_coef: 0.8929
# Epoch 00050: val_loss did not improve from 0.05502
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0628 - dice_coef: 0.8929 - val_loss: 0.0559 - val_dice_coef: 0.9043
# Epoch 51/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0625 - dice_coef: 0.8951
# Epoch 00051: val_loss did not improve from 0.05502
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0625 - dice_coef: 0.8951 - val_loss: 0.0588 - val_dice_coef: 0.9030
# Epoch 52/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0623 - dice_coef: 0.8899
# Epoch 00052: val_loss did not improve from 0.05502
# 30/30 [==============================] - 6s 210ms/step - loss: 0.0623 - dice_coef: 0.8899 - val_loss: 0.0570 - val_dice_coef: 0.9018
# Epoch 53/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0647 - dice_coef: 0.8919
# Epoch 00053: val_loss did not improve from 0.05502
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0647 - dice_coef: 0.8919 - val_loss: 0.0558 - val_dice_coef: 0.9023
# Epoch 54/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0602 - dice_coef: 0.8970
# Epoch 00054: val_loss did not improve from 0.05502
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0602 - dice_coef: 0.8970 - val_loss: 0.0578 - val_dice_coef: 0.9045
# Epoch 55/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0608 - dice_coef: 0.8976
# Epoch 00055: val_loss improved from 0.05502 to 0.05495, saving model to models/unet_fitted_model.h5
# 30/30 [==============================] - 9s 301ms/step - loss: 0.0608 - dice_coef: 0.8976 - val_loss: 0.0549 - val_dice_coef: 0.9040
# Epoch 56/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0593 - dice_coef: 0.8989
# Epoch 00056: val_loss improved from 0.05495 to 0.05461, saving model to models/unet_fitted_model.h5
# 30/30 [==============================] - 8s 260ms/step - loss: 0.0593 - dice_coef: 0.8989 - val_loss: 0.0546 - val_dice_coef: 0.9044
# Epoch 57/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0588 - dice_coef: 0.8999
# Epoch 00057: val_loss did not improve from 0.05461
# 30/30 [==============================] - 6s 210ms/step - loss: 0.0588 - dice_coef: 0.8999 - val_loss: 0.0559 - val_dice_coef: 0.9064
# Epoch 58/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0580 - dice_coef: 0.9003
# Epoch 00058: val_loss improved from 0.05461 to 0.05430, saving model to models/unet_fitted_model.h5
# 30/30 [==============================] - 8s 258ms/step - loss: 0.0580 - dice_coef: 0.9003 - val_loss: 0.0543 - val_dice_coef: 0.9070
# Epoch 59/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0586 - dice_coef: 0.9012
# Epoch 00059: val_loss did not improve from 0.05430
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0586 - dice_coef: 0.9012 - val_loss: 0.0554 - val_dice_coef: 0.9065
# Epoch 60/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0575 - dice_coef: 0.9019
# Epoch 00060: val_loss did not improve from 0.05430
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0575 - dice_coef: 0.9019 - val_loss: 0.0568 - val_dice_coef: 0.9047
# Epoch 61/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0574 - dice_coef: 0.9030
# Epoch 00061: val_loss did not improve from 0.05430
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0574 - dice_coef: 0.9030 - val_loss: 0.0546 - val_dice_coef: 0.9063
# Epoch 62/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0571 - dice_coef: 0.8986
# Epoch 00062: val_loss did not improve from 0.05430
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0571 - dice_coef: 0.8986 - val_loss: 0.0548 - val_dice_coef: 0.9072
# Epoch 63/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0566 - dice_coef: 0.9022
# Epoch 00063: val_loss did not improve from 0.05430
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0566 - dice_coef: 0.9022 - val_loss: 0.0544 - val_dice_coef: 0.9074
# Epoch 64/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0560 - dice_coef: 0.9036
# Epoch 00064: val_loss did not improve from 0.05430
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0560 - dice_coef: 0.9036 - val_loss: 0.0553 - val_dice_coef: 0.9097
# Epoch 65/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0573 - dice_coef: 0.9022
# Epoch 00065: val_loss did not improve from 0.05430
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0573 - dice_coef: 0.9022 - val_loss: 0.0544 - val_dice_coef: 0.9106
# Epoch 66/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0567 - dice_coef: 0.9025
# Epoch 00066: val_loss did not improve from 0.05430
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0567 - dice_coef: 0.9025 - val_loss: 0.0554 - val_dice_coef: 0.9093
# Epoch 67/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0557 - dice_coef: 0.9066
# Epoch 00067: val_loss improved from 0.05430 to 0.05414, saving model to models/unet_fitted_model.h5
# 30/30 [==============================] - 9s 302ms/step - loss: 0.0557 - dice_coef: 0.9066 - val_loss: 0.0541 - val_dice_coef: 0.9082
# Epoch 68/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0550 - dice_coef: 0.9042
# Epoch 00068: val_loss did not improve from 0.05414
# 30/30 [==============================] - 6s 210ms/step - loss: 0.0550 - dice_coef: 0.9042 - val_loss: 0.0559 - val_dice_coef: 0.9044
# Epoch 69/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0551 - dice_coef: 0.9055
# Epoch 00069: val_loss did not improve from 0.05414
# 30/30 [==============================] - 6s 210ms/step - loss: 0.0551 - dice_coef: 0.9055 - val_loss: 0.0559 - val_dice_coef: 0.9007
# Epoch 70/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0555 - dice_coef: 0.9044
# Epoch 00070: val_loss did not improve from 0.05414
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0555 - dice_coef: 0.9044 - val_loss: 0.0542 - val_dice_coef: 0.9121
# Epoch 71/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0555 - dice_coef: 0.9059
# Epoch 00071: val_loss did not improve from 0.05414
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0555 - dice_coef: 0.9059 - val_loss: 0.0557 - val_dice_coef: 0.9119
# Epoch 72/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0547 - dice_coef: 0.9062
# Epoch 00072: val_loss improved from 0.05414 to 0.05371, saving model to models/unet_fitted_model.h5
# 30/30 [==============================] - 9s 301ms/step - loss: 0.0547 - dice_coef: 0.9062 - val_loss: 0.0537 - val_dice_coef: 0.9058
# Epoch 73/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0540 - dice_coef: 0.9062
# Epoch 00073: val_loss did not improve from 0.05371
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0540 - dice_coef: 0.9062 - val_loss: 0.0538 - val_dice_coef: 0.9090
# Epoch 74/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0535 - dice_coef: 0.9080
# Epoch 00074: val_loss improved from 0.05371 to 0.05303, saving model to models/unet_fitted_model.h5
# 30/30 [==============================] - 10s 331ms/step - loss: 0.0535 - dice_coef: 0.9080 - val_loss: 0.0530 - val_dice_coef: 0.9093
# Epoch 75/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0533 - dice_coef: 0.9087
# Epoch 00075: val_loss did not improve from 0.05303
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0533 - dice_coef: 0.9087 - val_loss: 0.0535 - val_dice_coef: 0.9070
# Epoch 76/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0547 - dice_coef: 0.9069
# Epoch 00076: val_loss improved from 0.05303 to 0.05268, saving model to models/unet_fitted_model.h5
# 30/30 [==============================] - 8s 258ms/step - loss: 0.0547 - dice_coef: 0.9069 - val_loss: 0.0527 - val_dice_coef: 0.9078
# Epoch 77/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0537 - dice_coef: 0.9067
# Epoch 00077: val_loss did not improve from 0.05268
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0537 - dice_coef: 0.9067 - val_loss: 0.0538 - val_dice_coef: 0.9040
# Epoch 78/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0535 - dice_coef: 0.9070
# Epoch 00078: val_loss did not improve from 0.05268
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0535 - dice_coef: 0.9070 - val_loss: 0.0535 - val_dice_coef: 0.9113
# Epoch 79/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0533 - dice_coef: 0.9094
# Epoch 00079: val_loss improved from 0.05268 to 0.05247, saving model to models/unet_fitted_model.h5
# 30/30 [==============================] - 9s 310ms/step - loss: 0.0533 - dice_coef: 0.9094 - val_loss: 0.0525 - val_dice_coef: 0.9065
# Epoch 80/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0529 - dice_coef: 0.9078
# Epoch 00080: val_loss did not improve from 0.05247
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0529 - dice_coef: 0.9078 - val_loss: 0.0533 - val_dice_coef: 0.9118
# Epoch 81/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0517 - dice_coef: 0.9103
# Epoch 00081: val_loss did not improve from 0.05247
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0517 - dice_coef: 0.9103 - val_loss: 0.0528 - val_dice_coef: 0.9098
# Epoch 82/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0515 - dice_coef: 0.9100
# Epoch 00082: val_loss did not improve from 0.05247
# 30/30 [==============================] - 6s 210ms/step - loss: 0.0515 - dice_coef: 0.9100 - val_loss: 0.0535 - val_dice_coef: 0.9062
# Epoch 83/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0521 - dice_coef: 0.9105
# Epoch 00083: val_loss did not improve from 0.05247
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0521 - dice_coef: 0.9105 - val_loss: 0.0535 - val_dice_coef: 0.9087
# Epoch 84/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0514 - dice_coef: 0.9109
# Epoch 00084: val_loss improved from 0.05247 to 0.05219, saving model to models/unet_fitted_model.h5
# 30/30 [==============================] - 9s 308ms/step - loss: 0.0514 - dice_coef: 0.9109 - val_loss: 0.0522 - val_dice_coef: 0.9133
# Epoch 85/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0522 - dice_coef: 0.9110
# Epoch 00085: val_loss did not improve from 0.05219
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0522 - dice_coef: 0.9110 - val_loss: 0.0528 - val_dice_coef: 0.9079
# Epoch 86/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0521 - dice_coef: 0.9081
# Epoch 00086: val_loss did not improve from 0.05219
# 30/30 [==============================] - 6s 210ms/step - loss: 0.0521 - dice_coef: 0.9081 - val_loss: 0.0537 - val_dice_coef: 0.9135
# Epoch 87/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0532 - dice_coef: 0.9092
# Epoch 00087: val_loss did not improve from 0.05219
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0532 - dice_coef: 0.9092 - val_loss: 0.0535 - val_dice_coef: 0.9036
# Epoch 88/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0515 - dice_coef: 0.9100
# Epoch 00088: val_loss did not improve from 0.05219
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0515 - dice_coef: 0.9100 - val_loss: 0.0550 - val_dice_coef: 0.9101
# Epoch 89/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0521 - dice_coef: 0.9105
# Epoch 00089: val_loss did not improve from 0.05219
# 30/30 [==============================] - 6s 210ms/step - loss: 0.0521 - dice_coef: 0.9105 - val_loss: 0.0526 - val_dice_coef: 0.9098
# Epoch 90/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0511 - dice_coef: 0.9129
# Epoch 00090: val_loss improved from 0.05219 to 0.05218, saving model to models/unet_fitted_model.h5
# 30/30 [==============================] - 9s 306ms/step - loss: 0.0511 - dice_coef: 0.9129 - val_loss: 0.0522 - val_dice_coef: 0.9106
# Epoch 91/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0500 - dice_coef: 0.9088
# Epoch 00091: val_loss did not improve from 0.05218
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0500 - dice_coef: 0.9088 - val_loss: 0.0527 - val_dice_coef: 0.9093
# Epoch 92/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0500 - dice_coef: 0.9140
# Epoch 00092: val_loss did not improve from 0.05218
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0500 - dice_coef: 0.9140 - val_loss: 0.0522 - val_dice_coef: 0.9148
# Epoch 93/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0496 - dice_coef: 0.9148
# Epoch 00093: val_loss did not improve from 0.05218
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0496 - dice_coef: 0.9148 - val_loss: 0.0529 - val_dice_coef: 0.9116
# Epoch 94/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0494 - dice_coef: 0.9145
# Epoch 00094: val_loss improved from 0.05218 to 0.05188, saving model to models/unet_fitted_model.h5
# 30/30 [==============================] - 9s 307ms/step - loss: 0.0494 - dice_coef: 0.9145 - val_loss: 0.0519 - val_dice_coef: 0.9103
# Epoch 95/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0503 - dice_coef: 0.9122
# Epoch 00095: val_loss did not improve from 0.05188
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0503 - dice_coef: 0.9122 - val_loss: 0.0530 - val_dice_coef: 0.9090
# Epoch 96/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0499 - dice_coef: 0.9137
# Epoch 00096: val_loss did not improve from 0.05188
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0499 - dice_coef: 0.9137 - val_loss: 0.0525 - val_dice_coef: 0.9141
# Epoch 97/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0501 - dice_coef: 0.9145
# Epoch 00097: val_loss did not improve from 0.05188
# 30/30 [==============================] - 6s 210ms/step - loss: 0.0501 - dice_coef: 0.9145 - val_loss: 0.0525 - val_dice_coef: 0.9086
# Epoch 98/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0494 - dice_coef: 0.9126
# Epoch 00098: val_loss did not improve from 0.05188
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0494 - dice_coef: 0.9126 - val_loss: 0.0537 - val_dice_coef: 0.9107
# Epoch 99/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0488 - dice_coef: 0.9150
# Epoch 00099: val_loss did not improve from 0.05188
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0488 - dice_coef: 0.9150 - val_loss: 0.0526 - val_dice_coef: 0.9117
# Epoch 100/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0486 - dice_coef: 0.9145
# Epoch 00100: val_loss did not improve from 0.05188
# 30/30 [==============================] - 6s 211ms/step - loss: 0.0486 - dice_coef: 0.9145 - val_loss: 0.0535 - val_dice_coef: 0.9117
# Epoch 101/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0483 - dice_coef: 0.9169
# Epoch 00101: val_loss did not improve from 0.05188
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0483 - dice_coef: 0.9169 - val_loss: 0.0526 - val_dice_coef: 0.9151
# Epoch 102/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0490 - dice_coef: 0.9152
# Epoch 00102: val_loss did not improve from 0.05188
# 30/30 [==============================] - 6s 210ms/step - loss: 0.0490 - dice_coef: 0.9152 - val_loss: 0.0525 - val_dice_coef: 0.9110
# Epoch 103/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0496 - dice_coef: 0.9144
# Epoch 00103: val_loss did not improve from 0.05188
# 30/30 [==============================] - 6s 210ms/step - loss: 0.0496 - dice_coef: 0.9144 - val_loss: 0.0523 - val_dice_coef: 0.9121
# Epoch 104/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0505 - dice_coef: 0.9143
# Epoch 00104: val_loss did not improve from 0.05188
# 30/30 [==============================] - 6s 210ms/step - loss: 0.0505 - dice_coef: 0.9143 - val_loss: 0.0543 - val_dice_coef: 0.9098
# Epoch 105/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0497 - dice_coef: 0.9164
# Epoch 00105: val_loss did not improve from 0.05188
# 30/30 [==============================] - 6s 210ms/step - loss: 0.0497 - dice_coef: 0.9164 - val_loss: 0.0536 - val_dice_coef: 0.9047
# Epoch 106/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0498 - dice_coef: 0.9140
# Epoch 00106: val_loss did not improve from 0.05188
# 30/30 [==============================] - 6s 210ms/step - loss: 0.0498 - dice_coef: 0.9140 - val_loss: 0.0529 - val_dice_coef: 0.9112
# Epoch 107/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0489 - dice_coef: 0.9146
# Epoch 00107: val_loss did not improve from 0.05188
# 30/30 [==============================] - 6s 210ms/step - loss: 0.0489 - dice_coef: 0.9146 - val_loss: 0.0531 - val_dice_coef: 0.9131
# Epoch 108/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0474 - dice_coef: 0.9175
# Epoch 00108: val_loss improved from 0.05188 to 0.05163, saving model to models/unet_fitted_model.h5
# 30/30 [==============================] - 9s 310ms/step - loss: 0.0474 - dice_coef: 0.9175 - val_loss: 0.0516 - val_dice_coef: 0.9176
# Epoch 109/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0474 - dice_coef: 0.9187
# Epoch 00109: val_loss improved from 0.05163 to 0.05134, saving model to models/unet_fitted_model.h5
# 30/30 [==============================] - 8s 261ms/step - loss: 0.0474 - dice_coef: 0.9187 - val_loss: 0.0513 - val_dice_coef: 0.9131
# Epoch 110/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0472 - dice_coef: 0.9163
# Epoch 00110: val_loss did not improve from 0.05134
# 30/30 [==============================] - 6s 210ms/step - loss: 0.0472 - dice_coef: 0.9163 - val_loss: 0.0519 - val_dice_coef: 0.9115
# Epoch 111/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0496 - dice_coef: 0.9144
# Epoch 00111: val_loss did not improve from 0.05134
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0496 - dice_coef: 0.9144 - val_loss: 0.0523 - val_dice_coef: 0.9153
# Epoch 112/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0491 - dice_coef: 0.9156
# Epoch 00112: val_loss did not improve from 0.05134
# 30/30 [==============================] - 6s 210ms/step - loss: 0.0491 - dice_coef: 0.9156 - val_loss: 0.0523 - val_dice_coef: 0.9155
# Epoch 113/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0498 - dice_coef: 0.9139
# Epoch 00113: val_loss did not improve from 0.05134
# 30/30 [==============================] - 6s 210ms/step - loss: 0.0498 - dice_coef: 0.9139 - val_loss: 0.0524 - val_dice_coef: 0.9141
# Epoch 114/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0477 - dice_coef: 0.9174
# Epoch 00114: val_loss did not improve from 0.05134
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0477 - dice_coef: 0.9174 - val_loss: 0.0524 - val_dice_coef: 0.9139
# Epoch 115/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0464 - dice_coef: 0.9201
# Epoch 00115: val_loss did not improve from 0.05134
# 30/30 [==============================] - 6s 210ms/step - loss: 0.0464 - dice_coef: 0.9201 - val_loss: 0.0527 - val_dice_coef: 0.9138
# Epoch 116/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0466 - dice_coef: 0.9196
# Epoch 00116: val_loss did not improve from 0.05134
# 30/30 [==============================] - 6s 210ms/step - loss: 0.0466 - dice_coef: 0.9196 - val_loss: 0.0524 - val_dice_coef: 0.9117
# Epoch 117/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0478 - dice_coef: 0.9167
# Epoch 00117: val_loss did not improve from 0.05134
# 30/30 [==============================] - 6s 210ms/step - loss: 0.0478 - dice_coef: 0.9167 - val_loss: 0.0566 - val_dice_coef: 0.9096
# Epoch 118/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0469 - dice_coef: 0.9193
# Epoch 00118: val_loss did not improve from 0.05134
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0469 - dice_coef: 0.9193 - val_loss: 0.0524 - val_dice_coef: 0.9116
# Epoch 119/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0472 - dice_coef: 0.9167
# Epoch 00119: val_loss did not improve from 0.05134
# 30/30 [==============================] - 6s 210ms/step - loss: 0.0472 - dice_coef: 0.9167 - val_loss: 0.0535 - val_dice_coef: 0.9123
# Epoch 120/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0471 - dice_coef: 0.9182
# Epoch 00120: val_loss did not improve from 0.05134
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0471 - dice_coef: 0.9182 - val_loss: 0.0517 - val_dice_coef: 0.9146
# Epoch 121/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0457 - dice_coef: 0.9193
# Epoch 00121: val_loss did not improve from 0.05134
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0457 - dice_coef: 0.9193 - val_loss: 0.0529 - val_dice_coef: 0.9140
# Epoch 122/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0461 - dice_coef: 0.9212
# Epoch 00122: val_loss did not improve from 0.05134
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0461 - dice_coef: 0.9212 - val_loss: 0.0521 - val_dice_coef: 0.9138
# Epoch 123/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0448 - dice_coef: 0.9228
# Epoch 00123: val_loss did not improve from 0.05134
# 30/30 [==============================] - 6s 209ms/step - loss: 0.0448 - dice_coef: 0.9228 - val_loss: 0.0521 - val_dice_coef: 0.9164
# Epoch 124/150
# 30/30 [==============================] - ETA: 0s - loss: 0.0448 - dice_coef: 0.9219
# Epoch 00124: val_loss did not improve from 0.05134
# 30/30 [==============================] - 6s 211ms/step - loss: 0.0448 - dice_coef: 0.9219 - val_loss: 0.0522 - val_dice_coef: 0.9145

# %% [markdown]
# The model trained for a total of 124 rounds before early stopping ceased training.
#
# ---
#
# <a name="4"></a>
# # 4. Model Evaluation
#
# [Notebook Contents](#0) | [Summary](#6)
#
# ---
#
# ## Test Data Evaluation

# %%
def evaluate_model(model, X, y, history=None): 
    scores = model.evaluate(X, y, verbose=0) 
    print(' ') 
    print('Soft DICE Loss:', scores[0]) 
    print('DICE Coefficient:', scores[1]) 
    print(' ') 
    if history is not None: 
        print('Plotting Training Soft DICE Loss and DICE Coefficient:') 
        pd.DataFrame(history.history).plot(figsize=(10, 6)) 
        plt.grid(True) 
        plt.gca().set_ylim(0, 1) 
        plt.show() 

# model evaluation for test data 
print('Test Data Evaluation:') 
evaluate_model(model, X_test, y_test, history)
# Out:
# Test Data Evaluation:
#
# Soft DICE Loss: 0.0513436459004879
# DICE Coefficient: 0.9101377725601196
#
# Plotting Training Soft DICE Loss and DICE Coefficient:

# %% [markdown]
# ---
#
# ## Validation Data Evaluation
#
# * These are the unseen observations

# %%
# model evaluation for validation data 
print('Validation Data Evaluation:') 
evaluate_model(model, X_val, y_val)
# Out:
# Validation Data Evaluation:
#
# Soft DICE Loss: 0.0437399260699749
# DICE Coefficient: 0.9242769479751587

# %% [markdown]
# <a name="5"></a>
# # 5. Get Predictions and Plot
#
# [Notebook Contents](#0) | [Summary](#6)
#
# ---
#
# ## Section Outline
#
# * [Plot Train Predictions](#5-1)
# * [Plot Test Predictions](#5-2)
# * [Plot Validation Predictions](#5-3)
#
# ---
#
# ## Get Predictions

# %%
# get predictions 
preds_train = model.predict(X_train, verbose=0) 
preds_test = model.predict(X_test, verbose=0) 
preds_val = model.predict(X_val, verbose=0) 

# create binary mask 
preds_train_masks = (preds_train > 0.5).astype(np.uint8) 
preds_test_masks = (preds_test > 0.5).astype(np.uint8) 
preds_val_masks = (preds_val > 0.5).astype(np.uint8) 

# functions to visualize predictions 
def plot_img(X, cmap=None):  
    plt.imshow(X, cmap=cmap) 
    plt.axis('off') 

def plot_predictions(X, y, preds, cmap=None): 
    # get random observation number 
    idx = np.random.randint(len(X)) 
    # plot training image, mask, and prediction 
    plt.figure(figsize=(10, 6)) 
    plt.subplot(1, 3, 1) 
    plot_img(X[idx], cmap=cmap) 
    plt.title('Image', size=16) 
    plt.subplot(1, 3, 2) 
    plot_img(np.squeeze(y[idx]), cmap=cmap) 
    plt.title('Mask', size=16) 
    plt.subplot(1, 3, 3) 
    plot_img(np.squeeze(preds[idx]), cmap=cmap) 
    plt.title('Predicted Mask', size=16) 
    plt.suptitle('Observation Number: {}'.format(idx), size=18) 
    plt.tight_layout()

# %% [markdown]
# <a name="5-1"></a>
#
# ## Plot Train Predictions
#
# * [Section](#5)

# %%
# plot train predictions 
plot_predictions(X_train, y_train, preds_train_masks)

# %%
# plot train predictions 
plot_predictions(X_train, y_train, preds_train_masks)

# %%
# plot train predictions 
plot_predictions(X_train, y_train, preds_train_masks)

# %%
# plot train predictions 
plot_predictions(X_train, y_train, preds_train_masks)

# %% [markdown]
# <a name="5-2"></a>
#
# ## Plot Test Predictions
#
# * [Section](#5)

# %%
# plot test predictions 
plot_predictions(X_test, y_test, preds_test_masks)

# %%
# plot test predictions 
plot_predictions(X_test, y_test, preds_test_masks)

# %%
# plot test predictions 
plot_predictions(X_test, y_test, preds_test_masks)

# %%
# plot test predictions 
plot_predictions(X_test, y_test, preds_test_masks)

# %% [markdown]
# <a name="5-3"></a>
#
# ## Plot Validation Predictions
#
# * [Section](#5)
# * These are the unseen observations

# %%
# plot validation predictions 
plot_predictions(X_val, y_val, preds_val_masks)

# %%
# plot validation predictions 
plot_predictions(X_val, y_val, preds_val_masks)

# %%
# plot validation predictions 
plot_predictions(X_val, y_val, preds_val_masks)

# %%
# plot validation predictions 
plot_predictions(X_val, y_val, preds_val_masks)

# %%
# plot validation predictions 
plot_predictions(X_val, y_val, preds_val_masks)

# %%
# plot validation predictions 
plot_predictions(X_val, y_val, preds_val_masks)

# %% [markdown]
# <a name="6"></a>
#
# # 6. Summary
#
# [Notebook Contents](#0) | [Model Evaluation](#4) | [Get Predictions and Plot](#5)
#
# ---
#
# ### Model Evaluation
#
# * Train Data
#   * Soft DICE Loss: 0.0474
#   * DICE Coefficient: 0.9187
# * Test Data
#   * Soft DICE Loss: 0.0513
#   * DICE Coefficient: 0.9101
# * Validation Data
#   * Soft DICE Loss: 0.0437
#   * DICE Coefficient: 0.9243
